# %%
rivers = ['seti','kali','karnali']

# %%
rivers
# Out:
# ['seti', 'kali', 'karnali']

# %%
list1 = [1,1.25,'Bagmati',True,False,rivers]
list1
# Out:
# [1, 1.25, 'Bagmati', True, False, ['seti', 'kali', 'karnali']]

# %% [markdown]
# #Accessing items in list

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']

# %%
rivers[1:3]
# Out:
# ['Seti', 'Kali']

# %%
rivers[-3:-1]
# Out:
# ['Sun koshi', 'Karnali']

# %% [markdown]
# #Check if an item exists in list

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']

# %%
'Bagmati' in rivers
# Out:
# False

# %%
'Seti' in rivers
# Out:
# True

# %%
'Kali' not in rivers
# Out:
# False

# %% [markdown]
# #Change list items

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']

# %%
rivers[0]='Bagmati'
rivers
# Out:
# ['Bagmati', 'Seti', 'Kali', 'Rapti', 'Sun koshi', 'Karnali', 'Kamala']

# %%
rivers[1:3] = ['Tama Koshi','Sarda']
rivers
# Out:
# ['Bagmati', 'Tama Koshi', 'Sarda', 'Rapti', 'Sun koshi', 'Karnali', 'Kamala']

# %%
rivers.insert(2,'Narayani')
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala']

# %%
rivers.append("Mechi")
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi']

# %%
rivers2 = ['Arun','Tamor']
rivers.extend(rivers2)
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor']

# %%
len(rivers)
# Out:
# 11

# %%
river_tup = ('Dudh koshi','Indrawati')
rivers.extend(river_tup)
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati']

# %%
river_set = {'Rapti','Beni'}
rivers.extend(river_set)
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati',
#  'Beni',
#  'Rapti']

# %%
river_set = {'Bhote koshi','Amarawati'}
rivers.append(river_set)
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati',
#  'Beni',
#  'Rapti',
#  {'Amarawati', 'Bhote koshi'}]

# %% [markdown]
# #remove

# %%
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati',
#  'Beni',
#  'Rapti',
#  {'Amarawati', 'Bhote koshi'}]

# %%
rivers.remove('Beni')
len(rivers)
# Out:
# 15

# %%
print(len(rivers))
rivers.pop()
# Out:
# 15
# {'Amarawati', 'Bhote koshi'}

# %%
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Narayani',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati',
#  'Rapti']

# %%
rivers.pop(2)
# Out:
# 'Narayani'

# %%
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Dudh koshi',
#  'Indrawati',
#  'Rapti']

# %%
rivers.pop(-3)
# Out:
# 'Dudh koshi'

# %%
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Indrawati',
#  'Rapti']

# %%
del rivers[-2]

# %%
rivers
# Out:
# ['Bagmati',
#  'Tama Koshi',
#  'Sarda',
#  'Rapti',
#  'Sun koshi',
#  'Karnali',
#  'Kamala',
#  'Mechi',
#  'Arun',
#  'Tamor',
#  'Rapti']

# %%
del rivers

# %%
rivers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-f4e94c6cef70> in <cell line: 1>()
# ----> 1 rivers
#
# NameError: name 'rivers' is not defined

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']

# %%
rivers.clear()
rivers
# Out:
# []

# %% [markdown]
# #Loop and lists

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']
for river in rivers:
  print(river)

# %%
count = 0
for river in rivers:
  count += 1
print(count)
# Out:
# 7

# %%
for i in range(len(rivers)):
  print(i)

# %%
for i in range(len(rivers)):
  print(rivers[i])

# %%
[print(river) for river in rivers]

# %%
i=0
while i<len(rivers):
  print(rivers[i])
  i += 1

# %% [markdown]
# #List comprehension

# %%
[river for river in rivers]
# Out:
# ['Trishuli', 'Seti', 'Kali', 'Rapti', 'Sun koshi', 'Karnali', 'Kamala']

# %%
rivers2 = [river for river in rivers if "ti" in river]
rivers2
# Out:
# ['Seti', 'Rapti']

# %%
rivers2 =[]
for river in rivers:
  if 'ti' in river:
    rivers2.append(river)

# %%
rivers2
# Out:
# ['Seti', 'Rapti']

# %%
rivers = ['Trishuli','Seti','Kali','Rapti','Sun koshi','Karnali','Kamala']

# %%
upper_rivers = [river.upper() for river in rivers]
upper_rivers
# Out:
# ['TRISHULI', 'SETI', 'KALI', 'RAPTI', 'SUN KOSHI', 'KARNALI', 'KAMALA']

# %%
languages = ['Python','JS','C','C++',"JAVA"]

# %%
lang_list = [language if language == 'Python' else 'JS' for language in languages]

# %%
lang_list
# Out:
# ['Python', 'JS', 'JS', 'JS', 'JS']

# %% [markdown]
# #Sort List

# %%
languages = ['Python','JS','C','C++',"JAVA"]

# %%
languages.sort()

# %%
languages
# Out:
# ['C', 'C++', 'JAVA', 'JS', 'Python']

# %%
languages.sort(reverse=True)

# %%
languages
# Out:
# ['Python', 'JS', 'JAVA', 'C++', 'C']

# %%
list1 = [1,2.2,3.6,'banana']
list1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2436bd0a76fb> in <cell line: 2>()
#       1 list1 = [1,2.2,3.6,'banana']
# ----> 2 list1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']

# %%
languages.sort()
languages
# Out:
# ['C', 'C#', 'C++', 'Java', 'Perl', 'Python', 'js', 'prolog']

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']
languages.sort(key=str.lower)
languages
# Out:
# ['C', 'C#', 'C++', 'Java', 'js', 'Perl', 'prolog', 'Python']

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']
languages.sort(key=len)
languages
# Out:
# ['C', 'C#', 'js', 'C++', 'Java', 'Perl', 'prolog', 'Python']

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']
languages.sort(key=str.lower,reverse=True)
languages
# Out:
# ['Python', 'prolog', 'Perl', 'js', 'Java', 'C++', 'C#', 'C']

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']
languages.sorted()

# %%
languages = ['C','C++','C#','Java','js','prolog','Python','Perl']
sorted(languages)
# Out:
# ['C', 'C#', 'C++', 'Java', 'Perl', 'Python', 'js', 'prolog']

# %%
nums = [1,5,23,1,2]
sorted(nums)
# Out:
# [1, 1, 2, 5, 23]

# %% [markdown]
# #Copying list

# %%
languages = ["python","Pearl","Php"]

# %%
lang2 = languages
lang2
# Out:
# ['python', 'Pearl', 'Php']

# %%
lang3 = languages.copy()
lang3
# Out:
# ['python', 'Pearl', 'Php']

# %% [markdown]
# #Joining list

# %%
lang_1 = ['C','C++',"C#"]
lang_2 = ['Pearl',"Python","Php"]
lang_3 = lang_1 + lang_2

# %%
lang_3
# Out:
# ['C', 'C++', 'C#', 'Pearl', 'Python', 'Php']

# %%
for l in lang_2:
  lang_1.append(l)

# %%
lang_1
# Out:
# ['C', 'C++', 'C#', 'Pearl', 'Python', 'Php']

# %%
lang_1 = ['C','C++',"C#"]
lang_2 = ['Pearl',"Python","Php"]
lang_1.extend(lang_2)
lang_1
# Out:
# ['C', 'C++', 'C#', 'Pearl', 'Python', 'Php']

# %%
lang_1 = ['C','C++',"C#"]
lang_2 = ['Pearl',"Python","Php"]
lang_1 += lang_2
lang_1
# Out:
# ['C', 'C++', 'C#', 'Pearl', 'Python', 'Php']

# %% [markdown]
# #List Methods

# %%
#append()
#cleay()
#copy()
#count()
#extend()
#remove()
#insert()
#pop()
#reverse()

# %%
nums = [1,2,3,7,5,4,9]
nums.reverse()
nums
# Out:
# [9, 4, 5, 7, 3, 2, 1]

# %%
min(nums)
# Out:
# 1

# %%
max(nums)
# Out:
# 9

# %%
sum(nums)
# Out:
# 31

# %%
len(nums)
