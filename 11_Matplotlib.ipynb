# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
import numpy as np

# %%
xpoints = np.array([0,6,10])
ypoints = np.array([0,250,300])

# %%
xpoints
# Out:
# array([ 0,  6, 10])

# %%
ypoints
# Out:
# array([  0, 250, 300])

# %%
import numpy as np
import matplotlib.pypot as plt
x = np.array([0,1,2,3,4])
y = np.array([0,2,4,9,16])
plt.plot(x, y)
plt.show()

# %%
plt.plot(xpoints,ypoints,'x')
plt.show()

# %%
#multiple points
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([5,6,7,8,9])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
#xpoints = np.array([1,2,3,5])
ypoints = np.array([5,6,2,5])
plt.plot(ypoints,'o')
plt.show()

# %%
#xpoints = np.array([1,2,3,5])
ypoints = np.array([5,6,2,5])
plt.plot(ypoints,marker='o')
plt.show()

# %%
ypoints = np.array([5,6,2,0])
plt.plot(ypoints,'X:r')
plt.show()

# %%
ypoints = np.array([5,6,2,0])
plt.plot(ypoints,'o.r')
plt.show()
# Out:
# <ipython-input-45-ab35c7e12597>:2: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-.r" (-> linestyle='-.'). The keyword argument will take precedence.
#   plt.plot(ypoints,'o-.r',linestyle='dotted')

# %%
ypoints = np.array([5,6,2,0])
plt.plot(ypoints,linestyle='dotted', marker='o')
plt.show()
