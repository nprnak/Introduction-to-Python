# %% [markdown]
# #Introduction

# %%
import pandas as pd
import numpy as np

# %%
#Introduction
print("Pandas Version: ",pd.__version__)
# Out:
# Pandas Version:  2.0.3

# %% [markdown]
# #Basic Series

# %%
# Series
print("\n--- Series ---")
series = pd.Series([1, 3, 5, np.nan, 6, 8])
print(series)
# Out:
# --- Series ---
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
series
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# # DataFrame

# %%
print("\n--- DataFrame ---")
data = {
    'A': 1.,
    'B': pd.Timestamp('20230101'),
    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
    'D': np.array([3] * 4, dtype='int32'),
    'E': pd.Categorical(["test", "train", "test", "train"]),
    'F': 'foo'
}
df = pd.DataFrame(data)
print(df)
# Out:
# --- DataFrame ---
#      A          B    C  D      E    F
# 0  1.0 2023-01-01  1.0  3   test  foo
# 1  1.0 2023-01-01  1.0  3  train  foo
# 2  1.0 2023-01-01  1.0  3   test  foo
# 3  1.0 2023-01-01  1.0  3  train  foo

# %% [markdown]
# #Data manipulation

# %%
# Indexing and Selection
print("\n--- Indexing and Selection ---")
print(df['A'])
# Out:
# --- Indexing and Selection ---
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
print(df[0:2])
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-01  1.0  3   test  foo
# 1  1.0 2023-01-01  1.0  3  train  foo

# %%
print(df.loc[:, ['A', 'B']])
# Out:
#      A          B
# 0  1.0 2023-01-01
# 1  1.0 2023-01-01
# 2  1.0 2023-01-01
# 3  1.0 2023-01-01

# %%
print(df.iloc[0:2, 0:2])
# Out:
#      A          B
# 0  1.0 2023-01-01
# 1  1.0 2023-01-01

# %% [markdown]
# # Handling Missing Data

# %%
df2 = df.reindex(index=list(range(4)), columns=list(df.columns) + ['G'])

# %%
df2
# Out:
#      A          B    C  D      E    F   G
# 0  1.0 2023-01-01  1.0  3   test  foo NaN
# 1  1.0 2023-01-01  1.0  3  train  foo NaN
# 2  1.0 2023-01-01  1.0  3   test  foo NaN
# 3  1.0 2023-01-01  1.0  3  train  foo NaN

# %%
df2
# Out:
#      A          B    C  D      E    F   G
# 0  1.0 2023-01-01  1.0  3   test  foo NaN
# 1  1.0 2023-01-01  1.0  3  train  foo NaN
# 2  1.0 2023-01-01  1.0  3   test  foo NaN
# 3  1.0 2023-01-01  1.0  3  train  foo NaN

# %% [markdown]
# #Data Analysis

# %%
df3 = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar'],
    'B': ['one', 'one', 'two', 'two'],
    'C': np.random.randn(4),
    'D': np.random.randn(4)
})

# %%
df3
# Out:
#      A    B         C         D
# 0  foo  one -0.528412  0.841760
# 1  bar  one -1.461851  1.519108
# 2  foo  two -1.185904  1.121476
# 3  bar  two  0.450444 -0.234776

# %%
grouped = df3.groupby('A')
grouped.sum()
# Out:
#           B         C         D
# A
# bar  onetwo -1.011407  1.284332
# foo  onetwo -1.714316  1.963236
