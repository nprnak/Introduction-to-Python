# %% [markdown]
# #Basic

# %%
print("This is a string")
print("This is also \n a string")
#so is this
print('A')
# Out:
# This is a string
# This is also
#  a string
# A

# %%
type('A')
# Out:
# str

# %%
multiline_string = """
This is multiline string
This is line no 2
"""

# %%
type(multiline_string)
# Out:
# str

# %%
multiline_string = '''
This is multiline string
This is line no 2
'''

# %%
type(multiline_string)
# Out:
# str

# %%
str1 = "Learning Python"
len(str1)
# Out:
# 15

# %%
str1[2]
# Out:
# 'a'

# %%
str1[-1]
# Out:
# 'n'

# %%
str1[-5:]
# Out:
# 'ython'

# %%
str2 = 'Python'

# %%
for x in str2:
  print(x)
# Out:
# P
# y
# t
# h
# o
# n

# %%
'P' in str2
# Out:
# True

# %%
'p' in str2
# Out:
# False

# %% [markdown]
# #Modify string

# %%
str2 = 'python'

# %%
str2.upper()
# Out:
# 'PYTHON'

# %%
str3 = "class of python"

# %%
str3.upper()
# Out:
# 'CLASS OF PYTHON'

# %%
str3
# Out:
# 'class of python'

# %%
str3.title()
# Out:
# 'Class Of Python'

# %%
str4 = str3.upper()

# %%
str4
# Out:
# 'CLASS OF PYTHON'

# %%
str5 = str4.lower()
str5
# Out:
# 'class of python'

# %%
str6 = "         Removing the white      space        "
str6.strip()
# Out:
# 'Removing the white      space'

# %%
#replace
str7 = "banana"

# %%
str7.replace("n","N")
# Out:
# 'baNaNa'

# %%
str7 = str7.replace("n","N")

# %%
str7
# Out:
# 'baNaNa'

# %%
str8 = "Learning Python"
str8.replace("Python","Java")
# Out:
# 'Learning Java'

# %%
str8 = "Learning Python"
str8.split(" ")
# Out:
# ['Learning', 'Python']

# %%
str9 = "Life is \t what happens ,  to you \t when \t , you \n are busy making \n other \t plans,"
str9.split(" ")

# %%
str9 = "Life is \t what happens ,  to you \t when \t , you \n are busy making \n other \t plans,"
str9.split("\t")

# %%
str9 = "Life is \t what happens ,  to you \t when \t , you \n are busy making \n other \t plans,"
str9.split("o")

# %%
str9 = "Life is \t what happens ,  to you \t when \t , you \n are busy making \n other \t plans,"
str9.split("you")
# Out:
# ['Life is \t what happens ,  to ',
#  ' \t when \t , ',
#  ' \n are busy making \n other \t plans,']

# %%
str10 = "center"
str10.center(15)
# Out:
# '     center    '

# %% [markdown]
# #String Concatenation

# %%
str1 = "Welcome"
str2 = "Praful"
str3 = str1 + str2
str3
# Out:
# 'WelcomePraful'

# %%
str1 = "Welcome"
str2 = "Praful"
str3 = str1 + " "+str2
str3
# Out:
# 'Welcome Praful'

# %%
str1 = "Welcome"
str2 = "Praful"
str3 = str1 + "\n"+ str2
print(str3)
# Out:
# Welcome
# Praful

# %%
str1 = "Welcome"
str2 = "Praful"
str3 = str1 + "\t"+ str2
print(str3)
# Out:
# Welcome	Praful

# %% [markdown]
# #Escape characters

# %%
str1 = "He said: \"My name is Pravin\""
print(str1)
# Out:
# He said: "My name is Pravin"

# %%
str2 = "We need to use \n for new line"
print(str2)
# Out:
# We need to use
#  for new line

# %%
str2 = "We need to use \\n for new line"
print(str2)
# Out:
# We need to use \n for new line

# %%
#ASCII
str3 = "\101\102\103"
print(str3)
# Out:
# ABC

# %%
#ASCII
str3 = "\x41\x42\x43"
print(str3)
# Out:
# ABC

# %% [markdown]
# #String Function

# %%
#count
string = "She sells sheshells by the sheshore"

# %%
count = string.count("She")
print(count)
# Out:
# 1

# %%
#ends with
string = "She sells sheshells by the sheshore"
string.endswith("s")
# Out:
# False

# %%
#expandtabs
string = "This \t is a \t string"
print(string)
print(string.expandtabs(8))
print(string.expandtabs(4))
print(string.expandtabs(12))
print(string.expandtabs(25))
# Out:
# This 	 is a 	 string
# This     is a    string
# This     is a    string
# This         is a        string
# This                      is a                     string

# %%
#Find
string = "Fred fed Ted bread, and Ted fed Fred Bread"
string.find("Ted")
# Out:
# 9

# %%
#Check if all the characters in the text are alphanumeric
txt = "Company12"
print(txt.isalnum())
# Out:
# True

# %%
txt = "Company12"
print(txt.isalpha())
# Out:
# False

# %%
txt = "Company12"
print(txt.isdecimal())
# Out:
# False

# %%
txt = "12"
print(txt.isdecimal())
# Out:
# True

# %%
txt = "12.3"
print(txt.isdecimal())
# Out:
# False

# %%
txt = "12.3"
print(txt.isdigit())
# Out:
# False

# %%
txt = "1230000"
print(txt.isdecimal())
# Out:
# True

# %%
txt = "lower caSe"
txt.islower()
# Out:
# False

# %%
txt = "lower case"
txt.islower()
# Out:
# True

# %%
txt = "11"
print(txt.isnumeric())
# Out:
# True

# %%
txt = "Hello!\n How are you?"
txt.isprintable()
# Out:
# False

# %%
txt = "Hello!\\n How are you?"
txt.isprintable()
# Out:
# True

# %%
txt = "hello python"
txt2 = "Hello Python"
print(txt.istitle())
print(txt2.istitle())
# Out:
# False
# True

# %%
txt = "hello python"
txt2 = "Hello Python"
print(txt.isupper())
print(txt2.isupper())
# Out:
# False
# False

# %%
#join
#it joins all items in a tuple into a string, using a separator
books = ("Airport","Hotel","Zahir")
x = "&".join(books)
print(x)
# Out:
# Airport&Hotel&Zahir

# %%
books = ("Airport","Hotel","Zahir")
x = " ".join(books)
print(x)
# Out:
# Airport Hotel Zahir

# %%
books = ("Airport","Hotel","Zahir")
x = "...............".join(books)
print(x)
# Out:
# Airport...............Hotel...............Zahir

# %%
book = "Alchemist"
string = book.ljust(20)
print(string,"is a good novel")
# Out:
# Alchemist            is a good novel

# %%
book = "Alchemist"
string = book.rjust(20)
print(string,"is a good novel")
# Out:
#            Alchemist is a good novel

# %%
string = "Alchemist is best book bbbb"
mymap = string.maketrans("b","r")
print(string.translate(mymap))
# Out:
# Alchemist is rest rook rrrr

# %%
string = "An ape hates grape cakes"
x = string.partition("grape")
print(type(x))
# Out:
# <class 'tuple'>

# %%
string = "I scream, you scream \n we all scream \n for an icecream"
x = string.splitlines()
print(x)
# Out:
# ['I scream, you scream ', ' we all scream ', ' for an icecream']

# %%
string = "Four fine fresh Fish for You"
x = string.swapcase()
print(x)
# Out:
# fOUR FINE FRESH fISH FOR yOU

# %%
string = "50"
x = string.zfill(10)
print(x)
# Out:
# 0000000050
