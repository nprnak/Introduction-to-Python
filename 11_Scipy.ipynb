# %% [markdown]
# #Import

# %%
import scipy
scipy.__version__
# Out:
# '1.11.4'

# %% [markdown]
# #Constants

# %%
from scipy.constants import c,h
print(f"Speed of Light is:  {c} m/s")
print(f"Plank's Constant is: {h} JS")
# Out:
# Speed of Light is:  299792458.0 m/s
# Plank's Constant is: 6.62607015e-34 JS

# %% [markdown]
# #Integration

# %%
from scipy.integrate import quad
import numpy as np

def integrand(x):
    return np.exp(-x**2)

result, error = quad(integrand, 0, np.inf)
print(f"Result: {result}, error: {error}")
# Out:
# Result: 0.8862269254527579, error: 7.101318390472462e-09

# %%
np.inf
# Out:
# inf

# %%
def integrand(x):
    return np.sin(x)

result, error = quad(integrand,0,1)
print(f"Result: {result}, error: {error}")
# Out:
# Result: 0.45969769413186023, error: 5.103669643922839e-15
