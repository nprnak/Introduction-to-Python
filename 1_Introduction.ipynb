# %%
# !python -V
# Out:
# Python 3.11.13

# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# #The print statement

# %%
print("Welcome to Python Class")
# Out:
# Welcome to Python Class

# %%
print "Welcome to Python Class"
# Out:
#   Cell In[5], line 1
#     print "Welcome to Python Class"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# #comments

# %%
#this is comment

# %%
#this is comment
#this is another

# %%
"""
This is
multiple line comment
hkljkj
"""
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# #Variable

# %%
river = "Bagmati"
river
# Out:
# 'Bagmati'

# %%
River = "Bagmati"
River1="Koshi"
river = "Indrawati"

# %%
1river = "Narayani"
# Out:
#   Cell In[5], line 1
#     1river = "Narayani"
#     ^
# SyntaxError: invalid decimal literal

# %%
river_1 = "Narayani"
print(river_1)
# Out:
# Narayani

# %%
river-1 = "Bagmati"
# Out:
#   Cell In[7], line 1
#     river-1 = "Bagmati"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_river = "Gandaki"
_ = "Kamala"

# %%
____ = "Sun koshi"

# %%
____
# Out:
# 'Sun koshi'

# %%
_1 = "Tama koshi"

# %%
river1 = "Sunkoshi"
river2 = "Tama koshi"
print(river1)
river2
# Out:
# Sunkoshi
# 'Tama koshi'

# %%
class
int
float
def
for
while

# %%
x= 3
y= 3.0
z="pranaya"
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
# Out:
# 3
# 3.0
# pranaya
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# #Casting

# %%
x = '3'
print(type(x))
y =int(x)
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
x = int(x)
print(type(x))
# Out:
# <class 'int'>

# %%
x = float(x)
print(x)
print(type(x))
# Out:
# 3.0
# <class 'float'>

# %% [markdown]
# #Python Numbers

# %%
num1 = 1
num2 = 1.0
num3 = 1+1j
print(type(num1))
print(type(num2))
print(type(num3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
num4 = 0b1100
print(num4)
print(type(num4))
# Out:
# 12
# <class 'int'>

# %%
num5 = 0o23
print(num5)
print(type(num5))
# Out:
# 19
# <class 'int'>

# %%
num6 = 0x23
print(num6)
print(type(num6))
# Out:
# 35
# <class 'int'>

# %%
num7 = 2e3 #2x10^3
print(num7)
print(type(num7))
# Out:
# 2000.0
# <class 'float'>

# %%
num8 = 2E3 #2x10^3
print(num8)
print(type(num8))
# Out:
# 2000.0
# <class 'float'>

# %% [markdown]
# #User input in Python

# %%
city = input("Where do you live?")
print(city)
print(type(city))
# Out:
# kathmandu
# <class 'str'>

# %%
age = input("Enter your age: ")
print(age)
print(type(age))
age = int(age)
print(age)
print(type(age))
# Out:
# 30
# <class 'str'>
# 30
# <class 'int'>

# %%
#multiple user input
num1,num2,num3 = input("Enter two numbers").split()

# %%
num3
# Out:
# '3'

# %% [markdown]
# #Maths in Python

# %%
a = 2+2
a
# Out:
# 4

# %%
4-2
# Out:
# 2

# %%
4*3
# Out:
# 12

# %%
9/4
# Out:
# 2.25

# %%
9//4 #floor division
# Out:
# 2

# %%
11//4
# Out:
# 2

# %%
7%2
# Out:
# 1

# %%
2**4
# Out:
# 16

# %% [markdown]
# #Logical Operators in Python

# %%
num1 = 5
num2 = 10
print(num1 < 15 and num2 > 15)
# Out:
# False

# %%
num1 = 5
num2 = 10
print(num1 < 15 or num2 > 15)
# Out:
# True

# %%
print(not(num1 < 15))
# Out:
# False

# %% [markdown]
# #Membership operators in Python

# %%
name = "Clocks on wall"
find = "wall"
find in name
# Out:
# True

# %%
find not in name
# Out:
# False

# %% [markdown]
# #Identity operators in Python

# %%
x = 1
y = 2
print( x is y)
# Out:
# False

# %%
x = 1
y = 1
print( x is y)
# Out:
# True

# %%
x = 1
y = 2
print( x is not y)
# Out:
# True

# %%
x = 5
y = x
print(x is y)
# Out:
# True

# %% [markdown]
# #Python Bitwise operator

# %%
x = 0b1111
y = 0b1101
#

# %%
x & y
# Out:
# 13

# %%
x and y
# Out:
# 13

# %%
x or y
# Out:
# 15

# %%
x = 15
y = 13
x or y
# Out:
# 15

# %%
x = 14 #1110
y = 13 #1101
print(x ^ y)
# Out:
# 3

# %%
x = 5
~x
# Out:
# -6

# %%
num = -12
~num
# Out:
# 11

# %%
num = 0b0110
print(num)
num = num << 1 #0b1100
print(num)

# %%
num = 0b00000110
print(num)
num = num << 2 #00011000
print(num)

# %%
num = 0b00000110
print(num)
num = num >> 1
print(num)
# Out:
# 6
# 3

# %% [markdown]
# #Comparison operators

# %%
num = 6
num2 = 5
num == num2
# Out:
# False

# %%
num > num2
# Out:
# True

# %%
num < num2
# Out:
# False

# %%
num <= num2
# Out:
# False

# %%
num >= num2
# Out:
# True

# %%
num != num2

# %%
num ~= num2
# Out:
#   File "<ipython-input-75-926c3fac2a6f>", line 1
#     num ~= num2
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Assignment operator

# %%
x = 5
y=6
z=x
z
# Out:
# 5

# %%
z += 2 #z= z+2

# %%
z
# Out:
# 7

# %%
z -= 2 #z = z-2
z
# Out:
# 5

# %%
z *= 2 #z = z*2
z
# Out:
# 10

# %%
z /= 2 #z = z/2
z
# Out:
# 5.0

# %%
z %= 2 #z = z%2

# %%
z
# Out:
# 1.0

# %%
x = 23
x //=5 #x = x//5
x
# Out:
# 4

# %%
x = 0b0011
x <<=1 #x =x<<1
x

# %%
x = 0b0011
x >>=1 #x =x>>1
x
# Out:
# 1

# %%
x = 5 #101

x ^=2#010
x
# Out:
# 7

# %% [markdown]
# #Formatting output

# %%
x = 5
print(x)
# Out:
# 5

# %%
txt = "for only {price:.2f} dollars"
print(txt.format(price=49))
# Out:
# for only 49.00 dollars

# %%
txt = "For only {price:.3f} dollars"
print(txt.format(price=49.36579))
# Out:
# For only 49.366 dollars

# %%
txt1 = "My name is {fname}, I'm {age}".format(fname="Ali",age=36)
txt2 = "My name is {0},I'm {1}".format("Ali",36)
txt3 = "My name is {}, I'm {}".format("Ali",36)

# %%
print(txt1)
print(txt2)
print(txt3)
# Out:
# My name is Ali, I'm 36
# My name is Ali,I'm 36
# My name is Ali, I'm 36

# %%
txt2 = "My name is {1},I'm {0}".format("Ali",36)

# %%
txt2
# Out:
# "My name is 36,I'm Ali"

# %%
txt2 = "My name is {2},I'm {1}".format("Ali",36,35)
txt2
# Out:
# "My name is 35,I'm 36"

# %%
name = "Abdul"
age = 5
print(f"My name is {name}, I am {age} old")
# Out:
# My name is Abdul, I am 5 old

# %%
#use "<" to left align
num = 48
print(f"We have {num:<8} chickens")
# Out:
# We have 48       chickens

# %%
#use ">" to right align
num = 48
print(f"We have {num:>8} chickens")
# Out:
# We have       48 chickens

# %%
#use "^" to center align
num = 48
print(f"We have {num:^8} chickens")
# Out:
# We have    48    chickens

# %%
print("Number: %5.2f" %(5.33333))
print("Number: %5.2f" %(500.33333))
print("Number: %5.2f" %(500.33))
print("Number: %5.2f" %(50000.33))
print("Number: %5.2f" %(500000.33333))
# Out:
# Number:  5.33
# Number: 500.33
# Number: 500.33
# Number: 50000.33
# Number: 500000.33

# %%
print("Number: %15.2f" %(5.33333))
print("Number: %15.2f" %(500.33333))
print("Number: %15.2f" %(500.33))
print("Number: %15.2f" %(50000.33))
print("Number: %15.2f" %(500000.33333))
# Out:
# Number:            5.33
# Number:          500.33
# Number:          500.33
# Number:        50000.33
# Number:       500000.33

# %%
#print octal value
print("%o" %(23))
# Out:
# 27

# %%
#print hexa value
print("%x" %(30))
# Out:
# 1e

# %%
#print exponential value
print("%e"%(30056.871))
# Out:
# 3.005687e+04

# %%
print("My name is Praful \t I am from Patan")
# Out:
# My name is Praful 	 I am from Patan

# %%
print("My name is Praful \n I am from Patan")

# %% [markdown]
# #Random

# %%
#import a random module
import random

# %%
random.random()
# Out:
# 0.7629520915669845

# %%
random.seed(5)

# %%
random.random()
# Out:
# 0.7417869892607294

# %%
random.randint(-1001,1000)
# Out:
# -942

# %% [markdown]
# #this

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
