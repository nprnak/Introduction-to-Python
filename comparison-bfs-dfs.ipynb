# %% [markdown]
# <div class="header">
#     <h1>Lab: Comparison &ndash; BFS vs DFS</h1>
#     <p>CSC 266: Artificial Intelligence</p>
#     <p>Uninformed Search | Chapter 3.1</p>
# </div>
# <div class="note-box"><strong>Lab Objectives:</strong>
#     <ul>
#         <li>Implement both Breadth-First Search (BFS) and Depth-First Search (DFS)</li>
#         <li>Compare the traversal order of both algorithms on the same graph</li>
#         <li>Analyze the differences in path finding, memory usage, and completeness</li>
#         <li>Understand when to use BFS vs DFS</li>
#     </ul>
# </div>
# <hr />
# <h2 class="section-title">Part 1: Background</h2>
# <div class="card">
#     <h3><span class="badge">1</span> BFS vs DFS Overview</h3>
#     <div class="theory-box">
#         <p><strong>Breadth-First Search (BFS):</strong></p>
#         <ul>
#             <li>Explores graph level by level</li>
#             <li>Uses a Queue (FIFO)</li>
#             <li>Finds shortest path (unweighted graphs)</li>
#             <li>Complete and optimal</li>
#             <li>High memory usage</li>
#         </ul>
#     </div>
#     <div class="theory-box">
#         <p><strong>Depth-First Search (DFS):</strong></p>
#         <ul>
#             <li>Explores one branch completely before backtracking</li>
#             <li>Uses a Stack (LIFO)</li>
#             <li>Does NOT guarantee shortest path</li>
#             <li>Not complete (may go infinite depth)</li>
#             <li>Low memory usage</li>
#         </ul>
#     </div>
#     <div class="tree"><strong>Example Tree (BFS vs DFS traversal):</strong>
#         <pre>                A
#                / \
#               B   C
#              / \   \
#             D   E   F
#            /   / \   \
#           G   H   I   J
#
# BFS order: A, B, C, D, E, F, G, H, I, J
# DFS order (left-first): A, B, D, G, E, H, I, C, F, J</pre>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 2: Problem Description</h2>
# <div class="card">
#     <h3><span class="badge">2</span> Given Graph</h3>
#     <div class="tree"><strong>Graph Structure:</strong>
#         <pre>        A
#        / \
#       B   C
#      / \   \
#     D   E   F
#    /   / \   \
#   G   H   I   J</pre>
#     </div>
#     <div class="step-box">
#         <p><strong>Adjacency List Representation:</strong></p>
#         <ul>
#             <li>A is connected to: B, C</li>
#             <li>B is connected to: D, E</li>
#             <li>C is connected to: F</li>
#             <li>D is connected to: G, H</li>
#             <li>E is connected to: I</li>
#             <li>F is connected to: J</li>
#             <li>G, H, I, J have no children</li>
#         </ul>
#         <p><strong>Start Node:</strong> A</p>
#         <p><strong>Goal Node for Path Finding:</strong> I</p>
#         <p><strong>Edge Cost:</strong> All edges have cost = 1</p>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 3: Code</h2>
# <div class="card">
#     <h3><span class="badge">3</span> Complete Python Code</h3>
#     <div class="code-box">
#         <pre># Lab: Comparison - BFS vs DFS
# # Program by: [Your Name]
# # Roll no: [Your Roll No]
#
# graph = {
#     'A': ['B', 'C'],
#     'B': ['D', 'E'],
#     'C': ['F'],
#     'D': ['G', 'H'],
#     'E': ['I'],
#     'F': ['J'],
#     'G': [],
#     'H': [],
#     'I': [],
#     'J': []
# }
#
# ========== BFS IMPLEMENTATION ==========
# def bfs(graph, start, goal):
#     visited = []
#     queue = []
#
#     visited.append(start)
#     queue.append(start)
#
#     print("BFS Traversal: ", end='')
#
#     while queue:
#         m = queue.pop(0)
#         print(m, end=' ')
#
#         if m == goal:
#             print(f"\nBFS found goal: {goal}")
#             return
#
#         for neighbour in graph[m]:
#             if neighbour not in visited:
#                 visited.append(neighbour)
#                 queue.append(neighbour)
#
#     print(f"\nBFS did not find goal: {goal}")
#
# ========== DFS IMPLEMENTATION (ITERATIVE) ==========
# def dfs_iterative(graph, start, goal):
#     visited = []
#     stack = []
#
#     stack.append(start)
#     visited.append(start)
#
#     print("DFS Iterative Traversal: ", end='')
#
#     while stack:
#         m = stack.pop()
#         print(m, end=' ')
#
#         if m == goal:
#             print(f"\nDFS found goal: {goal}")
#             return
#
#         for neighbour in graph[m]:
#             if neighbour not in visited:
#                 visited.append(neighbour)
#                 stack.append(neighbour)
#
#     print(f"\nDFS did not find goal: {goal}")
#
# ========== DFS IMPLEMENTATION (RECURSIVE) ==========
# visited_recursive = []
#
# def dfs_recursive(graph, node, goal):
#     if node not in visited_recursive:
#         visited_recursive.append(node)
#         print(node, end=' ')
#
#         if node == goal:
#             return True
#
#         for neighbour in graph[node]:
#             if dfs_recursive(graph, neighbour, goal):
#                 return True
#         return False
#
# ========== MAIN PROGRAM ==========
# print("=" * 60)
# print("BFS vs DFS COMPARISON")
# print("=" * 60)
# print(f"\nGraph Adjacency List:")
# for node, neighbors in graph.items():
#     print(f"  {node} -&gt; {neighbors}")
# print(f"\nStart Node: A")
# print(f"Goal Node: I")
# print()
#
# print("=" * 60)
# bfs(graph, 'A', 'I')
# print()
#
# print("=" * 60)
# dfs_iterative(graph, 'A', 'I')
# print()
#
# print("=" * 60)
# print("DFS Recursive Traversal: ", end='')
# visited_recursive = []
# result = dfs_recursive(graph, 'A', 'I')
# print()
# if result:
#     print("DFS Recursive found goal: I")
# else:
#     print("DFS Recursive did not find goal: I")
# print()
#
# print("=" * 60)
# print("COMPARISON SUMMARY")
# print("=" * 60)
# print(f"{'Parameter':&lt;20} {'BFS':&lt;20} {'DFS':&lt;20}")
# print("-" * 60)
# print(f"{'Data Structure':&lt;20} {'Queue (FIFO)':&lt;20} {'Stack (LIFO)':&lt;20}")
# print(f"{'Traversal Order':&lt;20} {'Level by level':&lt;20} {'Depth first':&lt;20}")
# print(f"{'Finds Shortest Path?':&lt;20} {'Yes':&lt;20} {'No':&lt;20}")
# print(f"{'Memory Usage':&lt;20} {'High (O(b^d))':&lt;20} {'Low (O(bm))':&lt;20}")
# print(f"{'Complete?':&lt;20} {'Yes':&lt;20} {'No (may go infinite)':&lt;20}")
# print(f"{'Optimal?':&lt;20} {'Yes':&lt;20} {'No':&lt;20}")
#
# print("\n" + "=" * 60)
# print("Program by: [Your Name]")
# print("Roll No: [Your Roll No]")
#
# </pre>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 4: Expected Output</h2>
# <div class="card">
#     <h3><span class="badge">4</span> Program Output</h3>
#     <div class="output-box">
#         <pre>============================================================
# BFS vs DFS COMPARISON
# ============================================================
#
# Graph Adjacency List:
#   A -&gt; ['B', 'C']
#   B -&gt; ['D', 'E']
#   C -&gt; ['F']
#   D -&gt; ['G', 'H']
#   E -&gt; ['I']
#   F -&gt; ['J']
#   G -&gt; []
#   H -&gt; []
#   I -&gt; []
#   J -&gt; []
#
# Start Node: A
# Goal Node: I
#
# ============================================================
# BFS Traversal: A B C D E F G H I
# BFS found goal: I
#
# ============================================================
# DFS Iterative Traversal: A C F J B E I
# DFS found goal: I
#
# ============================================================
# DFS Recursive Traversal: A B D G H E I
# DFS Recursive found goal: I
#
# ============================================================
#
# COMPARISON SUMMARY
#
# ============================================================
#
# Parameter            BFS                  DFS
#
# ------------------------------------------------------------
# Data Structure       Queue (FIFO)         Stack (LIFO)
# Traversal Order      Level by level       Depth first
# Finds Shortest Path? Yes                  No
# Memory Usage         High (O(b^d))        Low (O(bm))
# Complete?            Yes                  No (may go infinite)
# Optimal?             Yes                  No
#
# ============================================================
# Program by: [Your Name]
# Roll No: [Your Roll No]
#
# </pre>
# </div>
# </div>
# <hr />
# <h2 class="section-title">Part 5: Tasks</h2>
# <div class="card">
#     <h3><span class="badge">5</span> Complete the Following Tasks</h3>
#     <div class="step-box">
#         <p><strong>Task 1:</strong> Write the BFS algorithm as shown in the code above.</p>
#         <p><strong>Task 2:</strong> Write the iterative DFS algorithm using a stack as shown in the code above.</p>
#         <p><strong>Task 3:</strong> Write the recursive DFS algorithm as shown in the code above.</p>
#         <p><strong>Task 4:</strong> Run the program on the given graph and record the output for both BFS and DFS.</p>
#         <p><strong>Task 5:</strong> Draw the graph structure (tree) based on the adjacency list.</p>
#         <p><strong>Task 6:</strong> Create your own graph with at least 10 nodes. Run both BFS and DFS on your graph and compare the traversal orders.</p>
#         <p><strong>Task 7:</strong> Answer the analysis questions below.</p>
#         <p><strong>Task 8:</strong> Create a comparison table of BFS vs DFS based on your observations.</p>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 6: Analysis Questions</h2>
# <div class="card">
#     <h3><span class="badge">6</span> Answer the Following Questions</h3>
#     <div class="step-box">
#         <p><strong>Question 1:</strong> What are the traversal orders for BFS and DFS on the given graph? List them.</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 2:</strong> Did BFS and DFS find the same path from A to I? If not, what were the different paths?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 3:</strong> Which algorithm found the shortest path from A to I? How many steps was it?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 4:</strong> What data structure does BFS use? Why is it suitable for level-by-level exploration?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 5:</strong> What data structure does iterative DFS use? Why is it suitable for depth-first exploration?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 6:</strong> What is the main advantage of BFS over DFS? What is the main advantage of DFS over BFS?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 7:</strong> In what scenarios would you choose BFS over DFS? When would you choose DFS over BFS?</p>
#     </div>
#     <div class="step-box">
#         <p><strong>Question 8:</strong> If the graph had weighted edges, would BFS still find the shortest path? Why or why not?</p>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 7: Sample Answers (For Reference)</h2>
# <div class="card">
#     <h3><span class="badge">A1</span> Question 1 Sample Answer</h3>
#     <div class="step-box">
#         <p><strong>BFS Traversal:</strong> A, B, C, D, E, F, G, H, I, J</p>
#         <p><strong>DFS Traversal (Iterative):</strong> A, C, F, J, B, E, I, D, H, G</p>
#         <p><strong>DFS Traversal (Recursive):</strong> A, B, D, G, H, E, I, C, F, J</p>
#     </div>
#     <h3><span class="badge">A2</span> Question 2 Sample Answer</h3>
#     <div class="step-box">
#         <p><strong>BFS path:</strong> A &rarr; B &rarr; E &rarr; I (3 steps)</p>
#         <p><strong>DFS path:</strong> A &rarr; B &rarr; E &rarr; I (same path in this graph, but DFS may not always find the shortest path)</p>
#         <p>In this graph, both found the same path, but DFS could have found A &rarr; B &rarr; D &rarr; ... (longer path) depending on neighbor order.</p>
#     </div>
#     <h3><span class="badge">A3</span> Question 3 Sample Answer</h3>
#     <div class="step-box">
#         <p>Both BFS and DFS found the same path A &rarr; B &rarr; E &rarr; I with 3 steps. BFS guarantees the shortest path, while DFS found it by chance in this graph.</p>
#     </div>
#     <h3><span class="badge">A4</span> Question 4 Sample Answer</h3>
#     <div class="step-box">
#         <p>BFS uses a Queue (FIFO &ndash; First In First Out). This ensures that nodes discovered earlier are processed before nodes discovered later, which gives the level-by-level exploration property.</p>
#     </div>
#     <h3><span class="badge">A5</span> Question 5 Sample Answer</h3>
#     <div class="step-box">
#         <p>Iterative DFS uses a Stack (LIFO &ndash; Last In First Out). This ensures that the most recently discovered node is processed next, allowing the algorithm to go deep into one branch before backtracking.</p>
#     </div>
#     <h3><span class="badge">A6</span> Question 6 Sample Answer</h3>
#     <div class="step-box">
#         <p><strong>Advantage of BFS:</strong> Finds the shortest path and is complete/optimal for unweighted graphs.</p>
#         <p><strong>Advantage of DFS:</strong> Uses much less memory (O(bm) vs O(b^d) for BFS).</p>
#     </div>
#     <h3><span class="badge">A7</span> Question 7 Sample Answer</h3>
#     <div class="step-box">
#         <p><strong>Choose BFS when:</strong> You need the shortest path, memory is not a constraint, and the goal is relatively shallow.</p>
#         <p><strong>Choose DFS when:</strong> Memory is limited, you only need any solution (not necessarily optimal), and you can limit the depth.</p>
#     </div>
#     <h3><span class="badge">A8</span> Question 8 Sample Answer</h3>
#     <div class="step-box">
#         <p><strong>No</strong>, BFS would not find the shortest path if edges have different costs. BFS only counts the number of steps, not the actual costs. For weighted graphs, Uniform Cost Search (UCS) or A* is needed.</p>
#     </div>
# </div>
# <hr />
# <h2 class="section-title">Part 8: Comparison Table</h2>
# <div class="card">
#     <h3><span class="badge">7</span> BFS vs DFS &ndash; Complete Comparison</h3>
#     <table class="comparison-table">
#         <tbody>
#             <tr style="background: #1a3a5c; color: white;">
#                 <th>Parameter</th>
#                 <th>BFS</th>
#                 <th>DFS</th>
#             </tr>
#             <tr>
#                 <td>Full Name</td>
#                 <td>Breadth-First Search</td>
#                 <td>Depth-First Search</td>
#             </tr>
#             <tr style="background: #f9f9f9;">
#                 <td>Data Structure</td>
#                 <td>Queue (FIFO)</td>
#                 <td>Stack (LIFO)</td>
#             </tr>
#             <tr>
#                 <td>Traversal Pattern</td>
#                 <td>Level by level</td>
#                 <td>Depth first, then backtrack</td>
#             </tr>
#             <tr style="background: #f9f9f9;">
#                 <td>Finds Shortest Path?</td>
#                 <td>Yes (unweighted graphs)</td>
#                 <td>No</td>
#             </tr>
#             <tr>
#                 <td>Complete?</td>
#                 <td>Yes</td>
#                 <td>No (may go infinite depth)</td>
#             </tr>
#             <tr style="background: #f9f9f9;">
#                 <td>Optimal?</td>
#                 <td>Yes (unweighted graphs)</td>
#                 <td>No</td>
#             </tr>
#             <tr>
#                 <td>Time Complexity</td>
#                 <td>O(V + E)</td>
#                 <td>O(V + E)</td>
#             </tr>
#             <tr style="background: #f9f9f9;">
#                 <td>Space Complexity</td>
#                 <td>O(V) - stores entire level</td>
#                 <td>O(V) - stores current path</td>
#             </tr>
#             <tr>
#                 <td>Memory Usage</td>
#                 <td>High</td>
#                 <td>Low</td>
#             </tr>
#             <tr style="background: #f9f9f9;">
#                 <td>Best Used When</td>
#                 <td>Goal is shallow, need shortest path</td>
#                 <td>Goal is deep, memory is limited</td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
# Lab: Comparison - BFS vs DFS
# Program by: [Your Name]
# Roll no: [Your Roll No]

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G', 'H'],
    'E': ['I'],
    'F': ['J'],
    'G': [],
    'H': [],
    'I': [],
    'J': []
}

# ========== BFS IMPLEMENTATION ==========
def bfs(graph, start, goal):
    visited = []
    queue = []
    
    visited.append(start)
    queue.append(start)
    
    print("BFS Traversal: ", end='')
    
    while queue:
        m = queue.pop(0)
        print(m, end=' ')
        
        if m == goal:
            print(f"\nBFS found goal: {goal}")
            return
        
        for neighbour in graph[m]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)
    
    print(f"\nBFS did not find goal: {goal}")

# ========== DFS IMPLEMENTATION (ITERATIVE) ==========
def dfs_iterative(graph, start, goal):
    visited = []
    stack = []
    
    stack.append(start)
    visited.append(start)
    
    print("DFS Iterative Traversal: ", end='')
    
    while stack:
        m = stack.pop()
        print(m, end=' ')
        
        if m == goal:
            print(f"\nDFS found goal: {goal}")
            return
        
        for neighbour in graph[m]:
            if neighbour not in visited:
                visited.append(neighbour)
                stack.append(neighbour)
    
    print(f"\nDFS did not find goal: {goal}")

# ========== DFS IMPLEMENTATION (RECURSIVE) ==========
visited_recursive = []

def dfs_recursive(graph, node, goal):
    if node not in visited_recursive:
        visited_recursive.append(node)
        print(node, end=' ')
        
        if node == goal:
            return True
        
        for neighbour in graph[node]:
            if dfs_recursive(graph, neighbour, goal):
                return True
        return False

# ========== MAIN PROGRAM ==========
print("=" * 60)
print("BFS vs DFS COMPARISON")
print("=" * 60)
print(f"\nGraph Adjacency List:")
for node, neighbors in graph.items():
    print(f"  {node} -> {neighbors}")
print(f"\nStart Node: A")
print(f"Goal Node: I")
print()

print("=" * 60)
bfs(graph, 'A', 'I')
print()

print("=" * 60)
dfs_iterative(graph, 'A', 'I')
print()

print("=" * 60)
print("DFS Recursive Traversal: ", end='')
visited_recursive = []
result = dfs_recursive(graph, 'A', 'I')
print()
if result:
    print("DFS Recursive found goal: I")
else:
    print("DFS Recursive did not find goal: I")
print()

print("=" * 60)
print("COMPARISON SUMMARY")
print("=" * 60)
print(f"{'Parameter':<20} {'BFS':<20} {'DFS':<20}")
print("-" * 60)
print(f"{'Data Structure':<20} {'Queue (FIFO)':<20} {'Stack (LIFO)':<20}")
print(f"{'Traversal Order':<20} {'Level by level':<20} {'Depth first':<20}")
print(f"{'Finds Shortest Path?':<20} {'Yes':<20} {'No':<20}")
print(f"{'Memory Usage':<20} {'High (O(b^d))':<20} {'Low (O(bm))':<20}")
print(f"{'Complete?':<20} {'Yes':<20} {'No (may go infinite)':<20}")
print(f"{'Optimal?':<20} {'Yes':<20} {'No':<20}")

print("\n" + "=" * 60)
print("Program by: [Your Name]")
print("Roll No: [Your Roll No]")
# Out:
# ...
# BFS vs DFS COMPARISON
# ...
#
# Graph Adjacency List:
#   A -> ['B', 'C']
#   B -> ['D', 'E']
#   C -> ['F']
#   D -> ['G', 'H']
#   E -> ['I']
#   F -> ['J']
#   G -> []
#   H -> []
#   I -> []
#   J -> []
#
# Start Node: A
# Goal Node: I
#
# ...
# BFS Traversal: A B C D E F G H I
# BFS found goal: I
#
# ...
# DFS Iterative Traversal: A C F J B E I
# DFS found goal: I
#
# ...
# DFS Recursive Traversal: A B D G H E I
# DFS Recursive found goal: I
#
# ...
# COMPARISON SUMMARY
# ...
# Parameter            BFS                  DFS
# ------------------------------------------------------------
# Data Structure       Queue (FIFO)         Stack (LIFO)
# Traversal Order      Level by level       Depth first
# Finds Shortest Path? Yes                  No
# Memory Usage         High (O(b^d))        Low (O(bm))
# Complete?            Yes                  No (may go infinite)
# Optimal?             Yes                  No
#
# ...
# Program by: [Your Name]
# Roll No: [Your Roll No]
